# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# %cd pytorch-cifar/
# Out:
# /content/drive/MyDrive/pytorch-cifar

# %%
# !python main.py
# Out:
# Namespace(lr=0.1, pr=None, resume=False, shot=None)
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
#  [================================================================>]  Step: 442ms | Tot: 21s463ms | Loss: 1.952 | Acc: 30.428% (15214/50000) 391/391
#  [================================================================>]  Step: 14ms | Tot: 1s517ms | Loss: 1.687 | Acc: 36.500% (3650/10000) 100/100
# Saving..
#
# Epoch: 1
#  [================================================================>]  Step: 37ms | Tot: 21s66ms | Loss: 1.479 | Acc: 45.698% (22849/50000) 391/391
#  [================================================================>]  Step: 14ms | Tot: 1s503ms | Loss: 1.390 | Acc: 50.550% (5055/10000) 100/100
# Saving..
#
# Epoch: 2
#  [================================================================>]  Step: 37ms | Tot: 21s88ms | Loss: 1.179 | Acc: 57.628% (28814/50000) 391/391
# ...

# %%
# !python main.py -pr 0.5 -shot 'single'
# Out:
# Namespace(lr=0.01, pr=0.5, resume=False, shot='single')
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ^C

# %%
# !python main.py -pr 0.9 -shot 'single'
# Out:
# Namespace(lr=0.1, pr=0.9, resume=False, shot='single')
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# Singel shot Sparsity run..
# Global sparsity: 90.00%
#  [================================================================>]  Step: 372ms | Tot: 21s77ms | Loss: 1.410 | Acc: 97.186% (48593/50000) 391/391
#  [================================================================>]  Step: 15ms | Tot: 1s572ms | Loss: 1.370 | Acc: 92.370% (9237/10000) 100/100
#  [================================================================>]  Step: 36ms | Tot: 20s774ms | Loss: 1.411 | Acc: 97.176% (48588/50000) 391/391
#  [================================================================>]  Step: 14ms | Tot: 1s559ms | Loss: 1.361 | Acc: 92.600% (9260/10000) 100/100
#  [================================================================>]  Step: 35ms | Tot: 20s726ms | Loss: 1.411 | Acc: 97.252% (48626/50000) 391/391
# ...

# %%
# !python main.py -pr 0.75 -shot 'single'
# Out:
# Namespace(lr=0.1, pr=0.75, resume=False, shot='single')
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# Singel shot Sparsity run..
# Global sparsity: 75.00%
#  [================================================================>]  Step: 372ms | Tot: 20s943ms | Loss: 0.085 | Acc: 99.976% (49988/50000) 391/391
#  [================================================================>]  Step: 15ms | Tot: 1s564ms | Loss: 0.205 | Acc: 95.090% (9509/10000) 100/100
#  [================================================================>]  Step: 35ms | Tot: 20s626ms | Loss: 0.086 | Acc: 99.966% (49983/50000) 391/391
#  [================================================================>]  Step: 15ms | Tot: 1s550ms | Loss: 0.206 | Acc: 95.050% (9505/10000) 100/100
#  [================================================================>]  Step: 35ms | Tot: 20s604ms | Loss: 0.086 | Acc: 99.962% (49981/50000) 391/391
# ...

# %%
# !python main.py -pr 0.5 -shot 'iter'
# Out:
# Namespace(lr=0.1, pr=0.5, resume=False, shot='iter')
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# Iterative Shot Sparsity run..
# Global sparsity: 11.00%
# Epoch 1 in iteration 1
#  [================================================================>]  Step: 421ms | Tot: 20s982ms | Loss: 0.002 | Acc: 99.998% (49999/50000) 391/391
# Epoch 2 in iteration 1
#  [================================================================>]  Step: 36ms | Tot: 20s565ms | Loss: 0.002 | Acc: 99.996% (49998/50000) 391/391
# Epoch 3 in iteration 1
#  [================================================================>]  Step: 36ms | Tot: 20s580ms | Loss: 0.002 | Acc: 99.998% (49999/50000) 391/391
# Epoch 4 in iteration 1
#  [================================================================>]  Step: 35ms | Tot: 20s598ms | Loss: 0.002 | Acc: 100.000% (50000/50000) 391/391
# Epoch 5 in iteration 1
# ...

# %%
# !python main.py -pr 0.75 -shot 'iter'
# Out:
# Namespace(lr=0.1, pr=0.75, resume=False, shot='iter')
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# Iterative Shot Sparsity run..
# Global sparsity: 11.00%
# Epoch 1 in iteration 1
#  [================================================================>]  Step: 370ms | Tot: 20s964ms | Loss: 0.002 | Acc: 99.994% (49997/50000) 391/391
# Epoch 2 in iteration 1
#  [================================================================>]  Step: 35ms | Tot: 20s643ms | Loss: 0.002 | Acc: 99.996% (49998/50000) 391/391
# Epoch 3 in iteration 1
#  [================================================================>]  Step: 36ms | Tot: 20s615ms | Loss: 0.002 | Acc: 99.994% (49997/50000) 391/391
# Epoch 4 in iteration 1
#  [================================================================>]  Step: 35ms | Tot: 20s604ms | Loss: 0.002 | Acc: 99.994% (49997/50000) 391/391
# Epoch 5 in iteration 1
# ...

# %%
# !python main.py -pr 0.9 -shot 'iter'
# Out:
# Namespace(lr=0.1, pr=0.9, resume=False, shot='iter')
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# Iterative Shot Sparsity run..
# Global sparsity: 11.00%
# Epoch 1 in iteration 1
#  [================================================================>]  Step: 367ms | Tot: 20s933ms | Loss: 0.002 | Acc: 99.998% (49999/50000) 391/391
# Epoch 2 in iteration 1
#  [================================================================>]  Step: 35ms | Tot: 20s600ms | Loss: 0.002 | Acc: 99.994% (49997/50000) 391/391
# Epoch 3 in iteration 1
#  [================================================================>]  Step: 35ms | Tot: 20s611ms | Loss: 0.002 | Acc: 99.998% (49999/50000) 391/391
# Epoch 4 in iteration 1
#  [================================================================>]  Step: 35ms | Tot: 20s585ms | Loss: 0.002 | Acc: 99.996% (49998/50000) 391/391
# Epoch 5 in iteration 1
# ...

# %%
# !python test.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Loading pre-trained model
#  [================================================================>]  Step: 433ms | Tot: 21s419ms | Loss: 0.002 | Acc: 99.998% (49999/50000) 391/391
#  [================================================================>]  Step: 14ms | Tot: 1s524ms | Loss: 0.171 | Acc: 95.410% (9541/10000) 100/100
# Loading single shot pruned model with sparsity of 0.5
# ==> Resuming from checkpoint..
# Sparsity run..
#  [================================================================>]  Step: 37ms | Tot: 21s343ms | Loss: 0.002 | Acc: 99.998% (49999/50000) 391/391
#  [================================================================>]  Step: 15ms | Tot: 1s567ms | Loss: 0.206 | Acc: 94.510% (9451/10000) 100/100
# Loading single shot pruned model with sparsity of 0.75
# ==> Resuming from checkpoint..
# Sparsity run..
# ...
